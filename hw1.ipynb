# %% [markdown]
# # Homework 1
# In this homework, we will have you train some convolutional neural networks! We will start with a small dataset (CIFAR), and then work our way up to TinyImageNet! This homework originally written by Daniel Gordon with very minor modifications.
#
# # Initial Setup
#
# This will authenticate Colab to connect to your google drive account. This way you have space to store the datasets and won't have to redownload them every time. You'll also have stable storage to save your best performing networks.

# %%
from google.colab import drive
drive.mount('/gdrive/')
# !ls /gdrive
# Out:
# Mounted at /gdrive/
# 'My Drive'

# %% [markdown]
# Run this code to navigate to the BASE_PATH directory and upload the homework2.tar file inside the BASE_PATH, then extract it.
#
# Have a look at [pt_util](https://gist.github.com/pjreddie/e531394d779af2da9201096af0dba78a). We moved some of the useful functions out of the python notebook to make it less cluttered, and added a few more useful functions.
#
# I made the BASE_PATH and DATA_PATH variables so you don't have to copy the same strings all over the place if you want to move the locations of the files around.

# %%
import os

BASE_PATH = '/gdrive/My Drive/colab_files/hw1/'
if not os.path.exists(BASE_PATH):
    os.makedirs(BASE_PATH)
DATA_PATH = BASE_PATH + 'tiny_imagenet/'

# !pwd
# !ls
os.chdir(BASE_PATH)
if not os.path.exists(DATA_PATH + 'train.h5'):
    # !wget https://courses.cs.washington.edu/courses/cse599g1/19au/files/homework2.tar
    # !tar -xvf homework2.tar
    # !rm homework2.tar
# !pwd
# !ls
os.chdir('/content')
# Out:
# /content
# sample_data
# /gdrive/My Drive/colab_files/hw1
# cifar  pt_util.py  __pycache__	tiny_imagenet

# %% [markdown]
# # CIFAR

# %% [markdown]
# ## Part 1: Getting the Dataset
# Normally, we'd want to download our dataset first. Since PyTorch hosts the CIFAR dataset, we can load it using their helper function later.
#
# But, we'll change DATA_PATH to an empty directory to download the dataset to.

# %%
DATA_PATH = BASE_PATH + 'cifar/'

# %% [markdown]
# ## Part 2: Defining the Network
# Just like with MNIST last homework we need to define our network architecture. This time we will be using convolutional layers and maxpooling to extract features from our images before we feed those features into our final classifier.
#
# Check out the documentation for [nn.Conv2d](https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html):
#
#     nn.Conv2d(in_channels, out_channels, kernel_size, stride = 1, padding = 0,...)
#
# So the first parameter is the number of channels in the input. Second is the number of filters we'll use (AKA number of channels in the output). Third is kernel size. Next is stride and padding which are optional and have default values.

# %%
import torch
import torch.nn as nn
from torchvision import datasets
from torchvision import transforms
import numpy as np
import os
import torch.nn.functional as F
import torch.optim as optim
import h5py
import sys
sys.path.append(BASE_PATH)
import pt_util

# %%
class CifarNet(nn.Module):
    def __init__(self):
        super(CifarNet, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, 3, stride=2, padding=1)
        self.conv2 = nn.Conv2d(16, 32, 3, stride=2, padding=1)
        self.conv3 = nn.Conv2d(32, 64, 3, stride=2, padding=1)
        self.fc1 = nn.Linear(1024, 10)
        self.accuracy = None

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = self.conv3(x)
        x = F.relu(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        return x

    def loss(self, prediction, label, reduction='mean'):
        loss_val = F.cross_entropy(prediction, label.squeeze(), reduction=reduction)
        return loss_val

    def save_model(self, file_path, num_to_keep=1):
        pt_util.save(self, file_path, num_to_keep)
        
    def save_best_model(self, accuracy, file_path, num_to_keep=1):
        if self.accuracy == None or accuracy > self.accuracy:
            self.accuracy = accuracy
            self.save_model(file_path, num_to_keep)

    def load_model(self, file_path):
        pt_util.restore(self, file_path)

    def load_last_model(self, dir_path):
        return pt_util.restore_latest(self, dir_path)

# %%
class AlexNet(nn.Module):
    def __init__(self):
        super(AlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=2, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(64, 192, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
        )
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 2 * 2, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Linear(4096, 10),
        )
        self.accuracy = None
    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), 256 * 2 * 2)
        x = self.classifier(x)
        return x
    
    def loss(self, prediction, label, reduction='mean'):
        loss_val = F.cross_entropy(prediction, label.squeeze(), reduction=reduction)
        return loss_val

    def save_model(self, file_path, num_to_keep=1):
        pt_util.save(self, file_path, num_to_keep)
        
    def save_best_model(self, accuracy, file_path, num_to_keep=1):
        if self.accuracy == None or accuracy > self.accuracy:
            self.accuracy = accuracy
            self.save_model(file_path, num_to_keep)

    def load_model(self, file_path):
        pt_util.restore(self, file_path)

    def load_last_model(self, dir_path):
        return pt_util.restore_latest(self, dir_path)

# %%
class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, kernel_size=5)
        self.conv2 = nn.Conv2d(6, 16, kernel_size=5)
        self.fc1 = nn.Linear(16*5*5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)
        self.accuracy = None
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x
    
    def loss(self, prediction, label, reduction='mean'):
        loss_val = F.cross_entropy(prediction, label.squeeze(), reduction=reduction)
        return loss_val

    def save_model(self, file_path, num_to_keep=1):
        pt_util.save(self, file_path, num_to_keep)
        
    def save_best_model(self, accuracy, file_path, num_to_keep=1):
        if self.accuracy == None or accuracy > self.accuracy:
            self.accuracy = accuracy
            self.save_model(file_path, num_to_keep)

    def load_model(self, file_path):
        pt_util.restore(self, file_path)

    def load_last_model(self, dir_path):
        return pt_util.restore_latest(self, dir_path)

# %%
cfg = {
    'VGG11': [64, 'M', 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'VGG13': [64, 64, 'M', 128, 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'VGG16': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],
    'VGG19': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 256, 'M', 512, 512, 512, 512, 'M', 512, 512, 512, 512, 'M'],
}

class VGG(nn.Module):
    def __init__(self, vgg_name):
        super(VGG, self).__init__()
        self.features = self._make_layers(cfg[vgg_name])
        self.classifier = nn.Linear(512, 10)
        self.accuracy = None

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x
    
    def _make_layers(self, cfg):
        layers = []
        in_channels = 3
        for x in cfg:
            if x == 'M':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            else:
                layers += [nn.Conv2d(in_channels, x, kernel_size=3, padding=1),
                           nn.BatchNorm2d(x),
                           nn.ReLU(inplace=True)]
                in_channels = x
        layers += [nn.AvgPool2d(kernel_size=1, stride=1)]
        return nn.Sequential(*layers)
    
    def loss(self, prediction, label, reduction='mean'):
        loss_val = F.cross_entropy(prediction, label.squeeze(), reduction=reduction)
        return loss_val

    def save_model(self, file_path, num_to_keep=1):
        pt_util.save(self, file_path, num_to_keep)
        
    def save_best_model(self, accuracy, file_path, num_to_keep=1):
        if self.accuracy == None or accuracy > self.accuracy:
            self.accuracy = accuracy
            self.save_model(file_path, num_to_keep)

    def load_model(self, file_path):
        pt_util.restore(self, file_path)

    def load_last_model(self, dir_path):
        return pt_util.restore_latest(self, dir_path)

# %% [markdown]
# This time we are giving you the train and test functions, but feel free to modify them if you want.
#
# You may need to return some additional information for the logging portion of this assignment.

# %%
import time
def train(model, device, train_loader, optimizer, epoch, log_interval):
    model.train()
    losses = []
    for batch_idx, (data, label) in enumerate(train_loader):
        data, label = data.to(device), label.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = model.loss(output, label)
        losses.append(loss.item())
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            print('{} Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                time.ctime(time.time()),
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
    return np.mean(losses)

def test(model, device, test_loader, log_interval=None):
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
        for batch_idx, (data, label) in enumerate(test_loader):
            data, label = data.to(device), label.to(device)
            output = model(data)
            test_loss_on = model.loss(output, label, reduction='sum').item()
            test_loss += test_loss_on
            pred = output.max(1)[1]
            correct_mask = pred.eq(label.view_as(pred))
            num_correct = correct_mask.sum().item()
            correct += num_correct
            if log_interval is not None and batch_idx % log_interval == 0:
                print('{} Test: [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                    time.ctime(time.time()),
                    batch_idx * len(data), len(test_loader.dataset),
                    100. * batch_idx / len(test_loader), test_loss_on))

    test_loss /= len(test_loader.dataset)
    test_accuracy = 100. * correct / len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset), test_accuracy))
    return test_loss, test_accuracy

# %% [markdown]
# ## Part 3 and 4: Loading Data and Dataset Augmentation
#
# In the MNIST assignment, we didn't do any data augmentation because MNIST is kind of easy.
#
# In this assignment, you may find that data augmentation helps you a lot (or possibly hurts your performance).
#
# You can find a bunch preimplemented here https://pytorch.org/docs/stable/torchvision/transforms.html and you can also do your own as seen in the tutorial from part 3.
#
# Play around with various data augmentations we will suggest some.
#
# - ToPILImage - This one is useful for a lot of the built in transforms which expect PIL images.
# - RandomHorizontalFlip
# - RandomResizedCrop
# - ColorJitter
# - RandomRotation
# - Normalize
# - Adding various types of noise
# - ToTensor - PyTorch expects the output from the dataset to be a tensor in CxHxW format.
#
#
# Note: You should be careful about which of these you apply to the test data. You usually don't want to apply noise to the test data, but you do want to normalize it in the same way for example.

# %%
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
])

data_train = datasets.CIFAR10(root=DATA_PATH, train=True, download=True, transform=transform_train)
data_test = datasets.CIFAR10(root=DATA_PATH, train=False, download=True, transform=transform_test)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Part 5: Training the network
# Generally, it is useful to see how your training is going. Often people print their loss to make sure it goes down and their accuracy to make sure it goes up. But pictures are better than words. So for this part, you should record and plot the training loss, test loss, and test accuracy (and whatever else you want).
#
# We have created a very simple logging interface which essentially just saves and restores files via pickle in pt_util. Saving and restoring log data is important if you end your run early and want to continue where you left off rather than starting over.
#
# We have also provided a plot function which can plot a single line graph. You can use it and plot each value independently, or change it to plot them all in one graph.
#
# Try different network architectures and experiment with hyperparameters. You'll answer the questions at the bottom of the file based on these experiments.
#
#
# __Important note: Do not forget to title your graphs and label your axes. Plots are meaningless without a way to read them.__
#
# Second Note: It will be helpful for you when deciding what network structure, data augmentation, and such work to title the graphs accordingly so you remember.
#
# Third Note: The default setup right now saves and restores the network weights from a single folder. When you modify network architectures, you may want to increment your experiment version number so you start over with your training and log files.

# %%
# Play around with these constants, you may find a better setting.
BATCH_SIZE = 256
TEST_BATCH_SIZE = 10
EPOCHS = 30
LEARNING_RATE = 0.01
MOMENTUM = 0.9
USE_CUDA = True
SEED = 0
PRINT_INTERVAL = 100
WEIGHT_DECAY = 0.0005

EXPERIMENT_VERSION = "0.5" # increment this to start a new experiment
LOG_PATH = DATA_PATH + 'logs/' + EXPERIMENT_VERSION + '/'

# Now the actual training code
use_cuda = USE_CUDA and torch.cuda.is_available()

#torch.manual_seed(SEED)

device = torch.device("cuda" if use_cuda else "cpu")
print('Using device', device)
import multiprocessing
print('num cpus:', multiprocessing.cpu_count())

kwargs = {'num_workers': multiprocessing.cpu_count(),
          'pin_memory': True} if use_cuda else {}

class_names = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

train_loader = torch.utils.data.DataLoader(data_train, batch_size=BATCH_SIZE,
                                           shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(data_test, batch_size=TEST_BATCH_SIZE,
                                          shuffle=False, **kwargs)

model = LeNet().to(device)
optimizer = optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)
start_epoch = model.load_last_model(LOG_PATH)

train_losses, test_losses, test_accuracies = pt_util.read_log(LOG_PATH + 'log.pkl', ([], [], []))
test_loss, test_accuracy = test(model, device, test_loader)

test_losses.append((start_epoch, test_loss))
test_accuracies.append((start_epoch, test_accuracy))

try:
    for epoch in range(start_epoch, EPOCHS + 1):
        train_loss = train(model, device, train_loader, optimizer, epoch, PRINT_INTERVAL)
        test_loss, test_accuracy = test(model, device, test_loader)
        train_losses.append((epoch, train_loss))
        test_losses.append((epoch, test_loss))
        test_accuracies.append((epoch, test_accuracy))
        pt_util.write_log(LOG_PATH + 'log.pkl', (train_losses, test_losses, test_accuracies))
        model.save_best_model(test_accuracy, LOG_PATH + '%03d.pt' % epoch)


except KeyboardInterrupt as ke:
    print('Interrupted')
except:
    import traceback
    traceback.print_exc()
finally:
    model.save_model(LOG_PATH + '%03d.pt' % epoch, 0)
    ep, val = zip(*train_losses)
    pt_util.plot(ep, val, 'Train loss', 'Epoch', 'Error')
    ep, val = zip(*test_losses)
    pt_util.plot(ep, val, 'Test loss', 'Epoch', 'Error')
    ep, val = zip(*test_accuracies)
    pt_util.plot(ep, val, 'Test accuracy', 'Epoch', 'Error')
# Out:
# Using device cuda
# num cpus: 2
# Restoring:
# conv1.weight -> 	torch.Size([6, 3, 5, 5]) = 0MB
# conv1.bias -> 	torch.Size([6]) = 0MB
# conv2.weight -> 	torch.Size([16, 6, 5, 5]) = 0MB
# conv2.bias -> 	torch.Size([16]) = 0MB
# fc1.weight -> 	torch.Size([120, 400]) = 0MB
# fc1.bias -> 	torch.Size([120]) = 0MB
# fc2.weight -> 	torch.Size([84, 120]) = 0MB
# fc2.bias -> 	torch.Size([84]) = 0MB
# fc3.weight -> 	torch.Size([10, 84]) = 0MB
# fc3.bias -> 	torch.Size([10]) = 0MB
#
# Restored all variables
# No new variables
# Restored /gdrive/My Drive/colab_files/hw1/cifar/logs/0.5/023.pt
#
# Test set: Average loss: 1.1648, Accuracy: 5905/10000 (59%)
#
# Thu Oct 29 20:04:01 2020 Train Epoch: 23 [0/50000 (0%)]	Loss: 1.147635
# Thu Oct 29 20:04:05 2020 Train Epoch: 23 [25600/50000 (51%)]	Loss: 1.226497
#
# Test set: Average loss: 1.1576, Accuracy: 5912/10000 (59%)
#
# Saved /gdrive/My Drive/colab_files/hw1/cifar/logs/0.5/023.pt
#
# Thu Oct 29 20:04:13 2020 Train Epoch: 24 [0/50000 (0%)]	Loss: 1.141177
# Thu Oct 29 20:04:18 2020 Train Epoch: 24 [25600/50000 (51%)]	Loss: 1.302582
#
# Test set: Average loss: 1.1480, Accuracy: 5924/10000 (59%)
#
# Saved /gdrive/My Drive/colab_files/hw1/cifar/logs/0.5/024.pt
#
# Thu Oct 29 20:04:25 2020 Train Epoch: 25 [0/50000 (0%)]	Loss: 1.194072
# Thu Oct 29 20:04:30 2020 Train Epoch: 25 [25600/50000 (51%)]	Loss: 1.241367
#
# Test set: Average loss: 1.1274, Accuracy: 6002/10000 (60%)
#
# Saved /gdrive/My Drive/colab_files/hw1/cifar/logs/0.5/025.pt
#
# Thu Oct 29 20:04:37 2020 Train Epoch: 26 [0/50000 (0%)]	Loss: 1.258848
# Thu Oct 29 20:04:42 2020 Train Epoch: 26 [25600/50000 (51%)]	Loss: 1.306626
#
# Test set: Average loss: 1.1135, Accuracy: 6105/10000 (61%)
#
# Saved /gdrive/My Drive/colab_files/hw1/cifar/logs/0.5/026.pt
#
# Thu Oct 29 20:04:49 2020 Train Epoch: 27 [0/50000 (0%)]	Loss: 1.119475
# Thu Oct 29 20:04:54 2020 Train Epoch: 27 [25600/50000 (51%)]	Loss: 1.242997
#
# Test set: Average loss: 1.1047, Accuracy: 6073/10000 (61%)
#
# Thu Oct 29 20:05:01 2020 Train Epoch: 28 [0/50000 (0%)]	Loss: 1.133972
# Thu Oct 29 20:05:06 2020 Train Epoch: 28 [25600/50000 (51%)]	Loss: 1.159143
#
# Test set: Average loss: 1.1019, Accuracy: 6131/10000 (61%)
#
# Saved /gdrive/My Drive/colab_files/hw1/cifar/logs/0.5/028.pt
#
# Thu Oct 29 20:05:13 2020 Train Epoch: 29 [0/50000 (0%)]	Loss: 1.179011
# Thu Oct 29 20:05:17 2020 Train Epoch: 29 [25600/50000 (51%)]	Loss: 1.184875
#
# Test set: Average loss: 1.0890, Accuracy: 6096/10000 (61%)
#
# Thu Oct 29 20:05:25 2020 Train Epoch: 30 [0/50000 (0%)]	Loss: 1.110443
# Thu Oct 29 20:05:29 2020 Train Epoch: 30 [25600/50000 (51%)]	Loss: 1.246264
#
# Test set: Average loss: 1.1335, Accuracy: 6002/10000 (60%)
#
# Saved /gdrive/My Drive/colab_files/hw1/cifar/logs/0.5/030.pt

# %% [markdown]
# ##CIFAR Questions
#
# 1. What design that you tried worked the best? This includes things like network design, learning rate, batch size, number of epochs, and other optimization parameters, data augmentation etc. What was the final train loss? Test loss? Test Accuracy? Provide the plots for train loss, test loss, and test accuracy.
#
# Our best model was the VGG19 from [this research paper](https://arxiv.org/abs/1409.1556) that consists of 16 convolutional layers and 3 fully connected layers. The VGG-19 have been trained on the ImageNet challenge (ILSVRC) 1000-class classification task, so we though it would be enough to classify 10-class from Cifar 10. (We have implemented VGG class above.) We actually tested Le Net and Alex Net as well, but this VGG19 was much better thatn other models.
#
# Additionally, there are the hyperparameters we used.
#
# - BATCH_SIZE = 256
# - TEST_BATCH_SIZE = 10
# - EPOCHS = 50
# - LEARNING_RATE = 0.01
# - MOMENTUM = 0.9
# - WEIGHT_DECAY = 0.0005
#
# We tested out different combinations of learning rate, mometum, and decay, but it won't change the result a lot, so we decided to increase the batch size. We have decided to use 50 to avoid overfitting.
#
# As a result, the average loss of test set was 0.4175 and the test accuracy was 89% (8936/10000)
#
# These are the plots for train loss, test loss, and test accuracy.

# %% [markdown]
# ![VGG19_Train_Loss.png](data:image/png;base64,...)
#
# ![VGG19_Test_Loss.png](data:image/png;base64,...)
#
# ![VGG_Test_Accuracy.png](data:image/png;base64,...)

# %% [markdown]
# 2. What design worked the worst (but still performed better than random chance)? Provide all the same information as question 1.
#
# Our worst model was the Le Net from [this research paper](http://yann.lecun.com/exdb/publis/pdf/lecun-98.pdf). We tried out this model since its accuracy for MNIST is around 99%. However, the result for Cifar-10 was not better than Alex Net or VGG19.
#
# Additionally, there are the hyperparameters we used.
#
# - BATCH_SIZE = 256
# - TEST_BATCH_SIZE = 10
# - EPOCHS = 30
# - LEARNING_RATE = 0.01
# - MOMENTUM = 0.9
# - WEIGHT_DECAY = 0.0005
#
# We tested out different combinations of learning rate, mometum, and decay, but it won't change the result a lot, so we decided to increase the batch size. We have decided to use 30 since its test loss and test accuracy start decreasing around 30 epocs. It means that the model gets overfitting to the train data in this point.
#
# As a result, the average loss of test set was 1.1335 and the test accuracy was 60% (6002/10000). It is slightly better thatn the default model with random values, but worse than other models.
#
# These are the plots for train loss, test loss, and test accuracy.

# %% [markdown]
# ![LetNet_Train_Loss.png](data:image/png;base64,...)
#
# ![LetNet_Test_Loss.png](data:image/png;base64,...)
#
# ![LetNet_Test_Accuracy.png](data:image/png;base64,...)

# %% [markdown]
# 3. Why do you think the best one worked well and the worst one worked poorly.
#
# Le Net worked poorly for Cifar-10 since it only have two sets of convolutional and max pooling layer. Its layer is more shallow than other recent model, so we believe that it might not classify if the dataset have more complicate features.
#
# VGG worked well for Cifar-10 compared to other models such as Le Net or Alex Net. According to [this research paper](https://arxiv.org/abs/1409.1556), VGG use 3 x 3 kernal and increase the number of convolutional layer (We use 19 layers this time). 　We guess that It is possible to compress more detailed feature of each image, so it results in the hight accuracy for our test data.

# %% [markdown]
# ---
# # TinyImageNet

# %% [markdown]
# ## Part 1: Upload the Dataset
# Change the DATA_PATH to the path of the TinyImageNet dataset we downloaded earlier.

# %%
DATA_PATH = BASE_PATH + 'tiny_imagenet/'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-276ede5bae6e> in <module>()
# ----> 1 DATA_PATH = BASE_PATH + 'tiny_imagenet/'
#
# NameError: name 'BASE_PATH' is not defined

# %% [markdown]
# ## Part 2: Defining the Network
# We're giving you no instructions on this part. Welcome to deep learning research! See if you can get above 40% accuracy. You probably want to use the Cross Entropy error again, but who knows, maybe you can find a better loss function. We will give you a few hints of things to try:
#
# - Maxpooling
# - Activation functions other than ReLU
# - Batch Norm
# - Dropout
# - Residual connections
#
# To define your network you'll have to figure out more about the Tiny ImageNet dataset. Specifically, what size are the images you'll be processing? How big is your label space? You can find this out by examining samples of your data.

# %%
import torch
import torch.nn as nn
from torchvision import datasets
from torchvision import transforms
import numpy as np
import os
import torch.nn.functional as F
import torch.optim as optim
import h5py
import sys
sys.path.append(BASE_PATH)
import pt_util

# %%
class WebBlock(nn.Module):
  def __init__(self, input, output, scale=1, stride=1):
    super(WebBlock, self).__init__()
    self.input, self.output = input, output
    self.scaled_output = self.output * scale
    self.activate = nn.ReLU(inplace=True)
    self.web_blocks = nn.Sequential(
        nn.Conv2d(self.input, self.output, kernel_size=3, stride=stride, padding=1), 
          nn.BatchNorm2d(self.output),
          self.activate,
          nn.Conv2d(self.output, self.scaled_output, kernel_size=3, padding=1), 
          nn.BatchNorm2d(self.scaled_output)
        )
    self.cast = nn.Sequential(
        nn.Conv2d(self.input, self.scaled_output, kernel_size=1, stride=stride,
                      bias=False), nn.BatchNorm2d(self.scaled_output)) if self.input != self.output else None  
    self.accuracy = None 
    
  def forward(self, x):
      web = x
      if self.cast: 
        web = self.cast(x)
      x = self.web_blocks(x)
      x += web
      x = self.activate(x)
      return x

class SpiderNet(nn.Module):
    def __init__(self, input=3):
      super(SpiderNet, self).__init__()
      net_channels = [32, 64, 128, 256]
      net_depths=[3,3,3,3]
        
      self.conv = nn.Sequential(
            nn.Conv2d(input, net_channels[0], kernel_size=7, stride=2, padding=3, bias=False),
            nn.BatchNorm2d(net_channels[0]),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
      )
        
      self.nets = nn.ModuleList([ 
            self.__make_spider_web(net_channels[0], net_channels[0], n=net_depths[0]),
            *[ self.__make_spider_web(input, output, n=n) 
              for input, output, n in zip(net_channels, net_channels[1:], net_depths[1:])]       
      ])
      self.avg = nn.AdaptiveAvgPool2d((1, 1))
      self.fc = nn.Linear(256, 200)
      self.accuracy = None

    def forward(self, x):
        x = self.conv(x)
        for net in self.nets:
            for web_block in net:
              x = web_block(x)
        x = self.avg(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

    def __make_spider_web(self, input, output, n=1):
        stride = 2 if input != output else 1
        return nn.ModuleList([
            WebBlock(input , output, stride=stride),
            *[WebBlock(output, 
                    output, stride=1) for _ in range(n - 1)]]
        )

    def loss(self, prediction, label, reduction='mean'):
        loss_val = F.cross_entropy(prediction, label.squeeze(), reduction=reduction)
        return loss_val

    def save_model(self, file_path, num_to_keep=1):
        pt_util.save(self, file_path, num_to_keep)
        
    def save_best_model(self, accuracy, file_path, num_to_keep=1):
        if self.accuracy == None or accuracy > self.accuracy:
            self.accuracy = accuracy
            self.save_model(file_path, num_to_keep)

    def load_model(self, file_path):
        pt_util.restore(self, file_path)

    def load_last_model(self, dir_path):
        return pt_util.restore_latest(self, dir_path)

# %% [markdown]
# This time we are giving you the train and test functions, but feel free to modify them if you want.
#
# You may need to return some additional information for the logging portion of this assignment.

# %%
import time
def train(model, device, train_loader, optimizer, epoch, log_interval):
    model.train()
    losses = []
    for batch_idx, (data, label) in enumerate(train_loader):
        data, label = data.to(device), label.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = model.loss(output, label)
        losses.append(loss.item())
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            print('{} Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                time.ctime(time.time()),
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
    return np.mean(losses)

def test(model, device, test_loader, return_images=False, log_interval=None):
    model.eval()
    test_loss = 0
    correct = 0

    correct_images = []
    correct_values = []

    error_images = []
    predicted_values = []
    gt_values = []
    with torch.no_grad():
        for batch_idx, (data, label) in enumerate(test_loader):
            data, label = data.to(device), label.to(device)
            output = model(data)
            test_loss_on = model.loss(output, label, reduction='sum').item()
            test_loss += test_loss_on
            pred = output.max(1)[1]
            correct_mask = pred.eq(label.view_as(pred))
            num_correct = correct_mask.sum().item()
            correct += num_correct
            if return_images:
                if num_correct > 0:
                    correct_images.append(data[correct_mask, ...].data.cpu().numpy())
                    correct_value_data = label[correct_mask].data.cpu().numpy()[:, 0]
                    correct_values.append(correct_value_data)
                if num_correct < len(label):
                    error_data = data[~correct_mask, ...].data.cpu().numpy()
                    error_images.append(error_data)
                    predicted_value_data = pred[~correct_mask].data.cpu().numpy()
                    predicted_values.append(predicted_value_data)
                    gt_value_data = label[~correct_mask].data.cpu().numpy()[:, 0]
                    gt_values.append(gt_value_data)
            if log_interval is not None and batch_idx % log_interval == 0:
                print('{} Test: [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                    time.ctime(time.time()),
                    batch_idx * len(data), len(test_loader.dataset),
                    100. * batch_idx / len(test_loader), test_loss_on))
    if return_images:
        correct_images = np.concatenate(correct_images, axis=0)
        error_images = np.concatenate(error_images, axis=0)
        predicted_values = np.concatenate(predicted_values, axis=0)
        correct_values = np.concatenate(correct_values, axis=0)
        gt_values = np.concatenate(gt_values, axis=0)

    test_loss /= len(test_loader.dataset)
    test_accuracy = 100. * correct / len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset), test_accuracy))
    if return_images:
        return test_loss, test_accuracy, correct_images, correct_values, error_images, predicted_values, gt_values
    else:
        return test_loss, test_accuracy

# %% [markdown]
# ## Part 3: Loading Data
# PyTorch has a nice interface for dealing with a variety of data. You can read a good tutorial here https://pytorch.org/tutorials/beginner/data_loading_tutorial.html
# Your friendly neighborhood TAs have made it even easier by preprocessing the data into a nice format. The data you uploaded is stored using hdf5 files which can be accessed a lot like Numpy arrays using the h5py package. In each of the files, there is a "dataset" called 'images', and one called 'labels'. Read more about h5py here http://docs.h5py.org/en/latest/quick.html
#
# Hints:
# 1. HDF5s don't support concurrent accesses.
# 2. If you don't close the HDF5 file, you will still have problems with concurrency.
# 3. One way to deal with concurrent accesses is to copy the entirety of the data into each process separately. Then each process accesses its own copy of the data. https://stackoverflow.com/questions/40449659/does-h5py-read-the-whole-file-into-memory
# 4. Speed hint: With small datasets, it is almost always a good idea to cache the data to disk rather than continually read from files.

# %%
# Data loader
class H5Dataset(torch.utils.data.Dataset):
    def __init__(self, h5_file, transform=None):
        self.transform = transform
        self.h5_file = h5py.File(h5_file, 'r')
        self.images = self.h5_file['images'][:]
        self.labels = torch.LongTensor(self.h5_file['labels'][:])
        
    def __len__(self):
        return self.labels.shape[0]
      
    def __getitem__(self, idx):
        data = self.images[idx]
        label = self.labels[idx]
        
        if self.transform:
            data = self.transform(data)
        return (data, label)

# %% [markdown]
# ## Part 4: Dataset Augmentation
# In the MNIST assignment, we didn't do any data augmentation because MNIST is kind of easy.
#
# In this assignment, you may find that data augmentation helps you a lot (or possibly hurts your performance).
#
# You can find a bunch preimplemented here https://pytorch.org/docs/stable/torchvision/transforms.html and you can also do your own as seen in the tutorial from part 3.
#
# Play around with various data augmentations we will suggest some.
#
# - ToPILImage - This one is useful for a lot of the built in transforms which expect PIL images.
# - RandomHorizontalFlip
# - RandomResizedCrop
# - ColorJitter
# - RandomRotation
# - Normalize
# - Adding various types of noise
# - ToTensor - PyTorch expects the output from the dataset to be a tensor in CxHxW format.
#
#
# Note: You should be careful about which of these you apply to the test data. You usually don't want to apply noise to the test data, but you do want to normalize it in the same way for example.

# %%
train_transforms = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    ])

test_transforms = transforms.Compose([
    transforms.ToTensor(),
    ])

data_train = H5Dataset(DATA_PATH + 'train.h5', transform=train_transforms)
print(len(data_train))
data_test = H5Dataset(DATA_PATH + 'val.h5', transform=test_transforms)
print(len(data_test))
# Out:
# 100000
# 8000

# %% [markdown]
# ## Part 5: Training the network
# Generally, it is useful to see how your training is going. Often people print their loss to make sure it goes down and their accuracy to make sure it goes up. But pictures are better than words. So for this part, you should record and plot the training loss, test loss, and test accuracy (and whatever else you want).
#
# We have created a very simple logging interface which essentially just saves and restores files via pickle in pt_util. Saving and restoring log data is important if you end your run early and want to continue where you left off rather than starting over.
#
# We have also provided a plot function which can plot a single line graph. You can use it and plot each value independently, or change it to plot them all in one graph.
#
#
# __Important note: Do not forget to title your graphs and label your axes. Plots are meaningless without a way to read them.__
#
# Second Note: It will be helpful for you when deciding what network structure, data augmentation, and such work to title the graphs accordingly so you remember.
# Third Note: The default setup right now saves and restores the network weights from a single folder. When you modify network architectures, you may want to save the resulting files in different folders (with appropriate names).
#
# We also provided a function for showing some results, because it's not satisfying to train a neural net, you also want to see what it can do! This can also be useful for figuring out what your network is doing well, and what it is failing at. This type of error analysis is very common when training neural networks.

# %%
# Play around with these constants, you may find a better setting.
BATCH_SIZE = 256
TEST_BATCH_SIZE = 10
EPOCHS = 20
LEARNING_RATE = 0.01
MOMENTUM = 0.9
USE_CUDA = True
SEED = 0
PRINT_INTERVAL = 100
WEIGHT_DECAY = 0.0005

EXPERIMENT_VERSION = "0.1" # increment this to start a new experiment
LOG_PATH = DATA_PATH + 'logs/' + EXPERIMENT_VERSION + '/'

# Now the actual training code
use_cuda = USE_CUDA and torch.cuda.is_available()

#torch.manual_seed(SEED)

device = torch.device("cuda" if use_cuda else "cpu")
print('Using device', device)
import multiprocessing
print('num cpus:', multiprocessing.cpu_count())

kwargs = {'num_workers': multiprocessing.cpu_count(),
          'pin_memory': True} if use_cuda else {}

class_names = [line.strip().split(', ') for line in open(DATA_PATH + 'class_names.txt')]
name_to_class = {line[1]: line[0] for line in class_names}
class_names = [line[1] for line in class_names]

train_loader = torch.utils.data.DataLoader(data_train, batch_size=BATCH_SIZE,
                                           shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(data_test, batch_size=TEST_BATCH_SIZE,
                                          shuffle=False, **kwargs)

model = SpiderNet().to(device)
optimizer = optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)
start_epoch = model.load_last_model(LOG_PATH)

train_losses, test_losses, test_accuracies = pt_util.read_log(LOG_PATH + 'log.pkl', ([], [], []))
test_loss, test_accuracy, correct_images, correct_val, error_images, predicted_val, gt_val = test(model, device, test_loader, True)

correct_images = pt_util.to_scaled_uint8(correct_images.transpose(0, 2, 3, 1))
error_images = pt_util.to_scaled_uint8(error_images.transpose(0, 2, 3, 1))
pt_util.show_images(correct_images, ['correct: %s' % class_names[aa] for aa in correct_val])
pt_util.show_images(error_images, ['pred: %s, actual: %s' % (class_names[aa], class_names[bb]) for aa, bb in zip(predicted_val, gt_val)])

test_losses.append((start_epoch, test_loss))
test_accuracies.append((start_epoch, test_accuracy))

try:
    for epoch in range(start_epoch, EPOCHS + 1):
        train_loss = train(model, device, train_loader, optimizer, epoch, PRINT_INTERVAL)
        test_loss, test_accuracy, correct_images, correct_val, error_images, predicted_val, gt_val = test(model, device, test_loader, True)
        train_losses.append((epoch, train_loss))
        test_losses.append((epoch, test_loss))
        test_accuracies.append((epoch, test_accuracy))
        pt_util.write_log(LOG_PATH + '.pkl', (train_losses, test_losses, test_accuracies))
        model.save_best_model(test_accuracy, LOG_PATH + '%03d.pt' % epoch)


except KeyboardInterrupt as ke:
    print('Interrupted')
except:
    import traceback
    traceback.print_exc()
finally:
    model.save_model(LOG_PATH + '%03d.pt' % epoch, 0)
    ep, val = zip(*train_losses)
    pt_util.plot(ep, val, 'Train loss', 'Epoch', 'Error')
    ep, val = zip(*test_losses)
    pt_util.plot(ep, val, 'Test loss', 'Epoch', 'Error')
    ep, val = zip(*test_accuracies)
    pt_util.plot(ep, val, 'Test accuracy', 'Epoch', 'Error')
    correct_images = pt_util.to_scaled_uint8(correct_images.transpose(0, 2, 3, 1))
    error_images = pt_util.to_scaled_uint8(error_images.transpose(0, 2, 3, 1))
    pt_util.show_images(correct_images, ['correct: %s' % class_names[aa] for aa in correct_val])
    pt_util.show_images(error_images, ['pred: %s, actual: %s' % (class_names[aa], class_names[bb]) for aa, bb in zip(predicted_val, gt_val)])
# Out:
# Using device cuda
# num cpus: 2
# Restoring:
# conv.0.weight -> 	torch.Size([32, 3, 7, 7]) = 0MB
# conv.1.weight -> 	torch.Size([32]) = 0MB
# conv.1.bias -> 	torch.Size([32]) = 0MB
# conv.1.running_mean -> 	torch.Size([32]) = 0MB
# conv.1.running_var -> 	torch.Size([32]) = 0MB
# conv.1.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.0.0.web_blocks.0.weight -> 	torch.Size([32, 32, 3, 3]) = 0MB
# nets.0.0.web_blocks.0.bias -> 	torch.Size([32]) = 0MB
# nets.0.0.web_blocks.1.weight -> 	torch.Size([32]) = 0MB
# nets.0.0.web_blocks.1.bias -> 	torch.Size([32]) = 0MB
# nets.0.0.web_blocks.1.running_mean -> 	torch.Size([32]) = 0MB
# nets.0.0.web_blocks.1.running_var -> 	torch.Size([32]) = 0MB
# nets.0.0.web_blocks.1.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.0.0.web_blocks.3.weight -> 	torch.Size([32, 32, 3, 3]) = 0MB
# nets.0.0.web_blocks.3.bias -> 	torch.Size([32]) = 0MB
# nets.0.0.web_blocks.4.weight -> 	torch.Size([32]) = 0MB
# nets.0.0.web_blocks.4.bias -> 	torch.Size([32]) = 0MB
# nets.0.0.web_blocks.4.running_mean -> 	torch.Size([32]) = 0MB
# nets.0.0.web_blocks.4.running_var -> 	torch.Size([32]) = 0MB
# nets.0.0.web_blocks.4.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.0.1.web_blocks.0.weight -> 	torch.Size([32, 32, 3, 3]) = 0MB
# nets.0.1.web_blocks.0.bias -> 	torch.Size([32]) = 0MB
# nets.0.1.web_blocks.1.weight -> 	torch.Size([32]) = 0MB
# nets.0.1.web_blocks.1.bias -> 	torch.Size([32]) = 0MB
# nets.0.1.web_blocks.1.running_mean -> 	torch.Size([32]) = 0MB
# nets.0.1.web_blocks.1.running_var -> 	torch.Size([32]) = 0MB
# nets.0.1.web_blocks.1.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.0.1.web_blocks.3.weight -> 	torch.Size([32, 32, 3, 3]) = 0MB
# nets.0.1.web_blocks.3.bias -> 	torch.Size([32]) = 0MB
# nets.0.1.web_blocks.4.weight -> 	torch.Size([32]) = 0MB
# nets.0.1.web_blocks.4.bias -> 	torch.Size([32]) = 0MB
# nets.0.1.web_blocks.4.running_mean -> 	torch.Size([32]) = 0MB
# nets.0.1.web_blocks.4.running_var -> 	torch.Size([32]) = 0MB
# nets.0.1.web_blocks.4.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.0.2.web_blocks.0.weight -> 	torch.Size([32, 32, 3, 3]) = 0MB
# nets.0.2.web_blocks.0.bias -> 	torch.Size([32]) = 0MB
# nets.0.2.web_blocks.1.weight -> 	torch.Size([32]) = 0MB
# nets.0.2.web_blocks.1.bias -> 	torch.Size([32]) = 0MB
# nets.0.2.web_blocks.1.running_mean -> 	torch.Size([32]) = 0MB
# nets.0.2.web_blocks.1.running_var -> 	torch.Size([32]) = 0MB
# nets.0.2.web_blocks.1.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.0.2.web_blocks.3.weight -> 	torch.Size([32, 32, 3, 3]) = 0MB
# nets.0.2.web_blocks.3.bias -> 	torch.Size([32]) = 0MB
# nets.0.2.web_blocks.4.weight -> 	torch.Size([32]) = 0MB
# nets.0.2.web_blocks.4.bias -> 	torch.Size([32]) = 0MB
# nets.0.2.web_blocks.4.running_mean -> 	torch.Size([32]) = 0MB
# nets.0.2.web_blocks.4.running_var -> 	torch.Size([32]) = 0MB
# nets.0.2.web_blocks.4.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.1.0.web_blocks.0.weight -> 	torch.Size([64, 32, 3, 3]) = 0MB
# nets.1.0.web_blocks.0.bias -> 	torch.Size([64]) = 0MB
# nets.1.0.web_blocks.1.weight -> 	torch.Size([64]) = 0MB
# nets.1.0.web_blocks.1.bias -> 	torch.Size([64]) = 0MB
# nets.1.0.web_blocks.1.running_mean -> 	torch.Size([64]) = 0MB
# nets.1.0.web_blocks.1.running_var -> 	torch.Size([64]) = 0MB
# nets.1.0.web_blocks.1.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.1.0.web_blocks.3.weight -> 	torch.Size([64, 64, 3, 3]) = 0MB
# nets.1.0.web_blocks.3.bias -> 	torch.Size([64]) = 0MB
# nets.1.0.web_blocks.4.weight -> 	torch.Size([64]) = 0MB
# nets.1.0.web_blocks.4.bias -> 	torch.Size([64]) = 0MB
# nets.1.0.web_blocks.4.running_mean -> 	torch.Size([64]) = 0MB
# nets.1.0.web_blocks.4.running_var -> 	torch.Size([64]) = 0MB
# nets.1.0.web_blocks.4.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.1.0.cast.0.weight -> 	torch.Size([64, 32, 1, 1]) = 0MB
# nets.1.0.cast.1.weight -> 	torch.Size([64]) = 0MB
# nets.1.0.cast.1.bias -> 	torch.Size([64]) = 0MB
# nets.1.0.cast.1.running_mean -> 	torch.Size([64]) = 0MB
# nets.1.0.cast.1.running_var -> 	torch.Size([64]) = 0MB
# nets.1.0.cast.1.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.1.1.web_blocks.0.weight -> 	torch.Size([64, 64, 3, 3]) = 0MB
# nets.1.1.web_blocks.0.bias -> 	torch.Size([64]) = 0MB
# nets.1.1.web_blocks.1.weight -> 	torch.Size([64]) = 0MB
# nets.1.1.web_blocks.1.bias -> 	torch.Size([64]) = 0MB
# nets.1.1.web_blocks.1.running_mean -> 	torch.Size([64]) = 0MB
# nets.1.1.web_blocks.1.running_var -> 	torch.Size([64]) = 0MB
# nets.1.1.web_blocks.1.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.1.1.web_blocks.3.weight -> 	torch.Size([64, 64, 3, 3]) = 0MB
# nets.1.1.web_blocks.3.bias -> 	torch.Size([64]) = 0MB
# nets.1.1.web_blocks.4.weight -> 	torch.Size([64]) = 0MB
# nets.1.1.web_blocks.4.bias -> 	torch.Size([64]) = 0MB
# nets.1.1.web_blocks.4.running_mean -> 	torch.Size([64]) = 0MB
# nets.1.1.web_blocks.4.running_var -> 	torch.Size([64]) = 0MB
# nets.1.1.web_blocks.4.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.1.2.web_blocks.0.weight -> 	torch.Size([64, 64, 3, 3]) = 0MB
# nets.1.2.web_blocks.0.bias -> 	torch.Size([64]) = 0MB
# nets.1.2.web_blocks.1.weight -> 	torch.Size([64]) = 0MB
# nets.1.2.web_blocks.1.bias -> 	torch.Size([64]) = 0MB
# nets.1.2.web_blocks.1.running_mean -> 	torch.Size([64]) = 0MB
# nets.1.2.web_blocks.1.running_var -> 	torch.Size([64]) = 0MB
# nets.1.2.web_blocks.1.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.1.2.web_blocks.3.weight -> 	torch.Size([64, 64, 3, 3]) = 0MB
# nets.1.2.web_blocks.3.bias -> 	torch.Size([64]) = 0MB
# nets.1.2.web_blocks.4.weight -> 	torch.Size([64]) = 0MB
# nets.1.2.web_blocks.4.bias -> 	torch.Size([64]) = 0MB
# nets.1.2.web_blocks.4.running_mean -> 	torch.Size([64]) = 0MB
# nets.1.2.web_blocks.4.running_var -> 	torch.Size([64]) = 0MB
# nets.1.2.web_blocks.4.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.2.0.web_blocks.0.weight -> 	torch.Size([128, 64, 3, 3]) = 0MB
# nets.2.0.web_blocks.0.bias -> 	torch.Size([128]) = 0MB
# nets.2.0.web_blocks.1.weight -> 	torch.Size([128]) = 0MB
# nets.2.0.web_blocks.1.bias -> 	torch.Size([128]) = 0MB
# nets.2.0.web_blocks.1.running_mean -> 	torch.Size([128]) = 0MB
# nets.2.0.web_blocks.1.running_var -> 	torch.Size([128]) = 0MB
# nets.2.0.web_blocks.1.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.2.0.web_blocks.3.weight -> 	torch.Size([128, 128, 3, 3]) = 0MB
# nets.2.0.web_blocks.3.bias -> 	torch.Size([128]) = 0MB
# nets.2.0.web_blocks.4.weight -> 	torch.Size([128]) = 0MB
# nets.2.0.web_blocks.4.bias -> 	torch.Size([128]) = 0MB
# nets.2.0.web_blocks.4.running_mean -> 	torch.Size([128]) = 0MB
# nets.2.0.web_blocks.4.running_var -> 	torch.Size([128]) = 0MB
# nets.2.0.web_blocks.4.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.2.0.cast.0.weight -> 	torch.Size([128, 64, 1, 1]) = 0MB
# nets.2.0.cast.1.weight -> 	torch.Size([128]) = 0MB
# nets.2.0.cast.1.bias -> 	torch.Size([128]) = 0MB
# nets.2.0.cast.1.running_mean -> 	torch.Size([128]) = 0MB
# nets.2.0.cast.1.running_var -> 	torch.Size([128]) = 0MB
# nets.2.0.cast.1.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.2.1.web_blocks.0.weight -> 	torch.Size([128, 128, 3, 3]) = 0MB
# nets.2.1.web_blocks.0.bias -> 	torch.Size([128]) = 0MB
# nets.2.1.web_blocks.1.weight -> 	torch.Size([128]) = 0MB
# nets.2.1.web_blocks.1.bias -> 	torch.Size([128]) = 0MB
# nets.2.1.web_blocks.1.running_mean -> 	torch.Size([128]) = 0MB
# nets.2.1.web_blocks.1.running_var -> 	torch.Size([128]) = 0MB
# nets.2.1.web_blocks.1.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.2.1.web_blocks.3.weight -> 	torch.Size([128, 128, 3, 3]) = 0MB
# nets.2.1.web_blocks.3.bias -> 	torch.Size([128]) = 0MB
# nets.2.1.web_blocks.4.weight -> 	torch.Size([128]) = 0MB
# nets.2.1.web_blocks.4.bias -> 	torch.Size([128]) = 0MB
# nets.2.1.web_blocks.4.running_mean -> 	torch.Size([128]) = 0MB
# nets.2.1.web_blocks.4.running_var -> 	torch.Size([128]) = 0MB
# nets.2.1.web_blocks.4.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.2.2.web_blocks.0.weight -> 	torch.Size([128, 128, 3, 3]) = 0MB
# nets.2.2.web_blocks.0.bias -> 	torch.Size([128]) = 0MB
# nets.2.2.web_blocks.1.weight -> 	torch.Size([128]) = 0MB
# nets.2.2.web_blocks.1.bias -> 	torch.Size([128]) = 0MB
# nets.2.2.web_blocks.1.running_mean -> 	torch.Size([128]) = 0MB
# nets.2.2.web_blocks.1.running_var -> 	torch.Size([128]) = 0MB
# nets.2.2.web_blocks.1.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.2.2.web_blocks.3.weight -> 	torch.Size([128, 128, 3, 3]) = 0MB
# nets.2.2.web_blocks.3.bias -> 	torch.Size([128]) = 0MB
# nets.2.2.web_blocks.4.weight -> 	torch.Size([128]) = 0MB
# nets.2.2.web_blocks.4.bias -> 	torch.Size([128]) = 0MB
# nets.2.2.web_blocks.4.running_mean -> 	torch.Size([128]) = 0MB
# nets.2.2.web_blocks.4.running_var -> 	torch.Size([128]) = 0MB
# nets.2.2.web_blocks.4.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.3.0.web_blocks.0.weight -> 	torch.Size([256, 128, 3, 3]) = 1MB
# nets.3.0.web_blocks.0.bias -> 	torch.Size([256]) = 0MB
# nets.3.0.web_blocks.1.weight -> 	torch.Size([256]) = 0MB
# nets.3.0.web_blocks.1.bias -> 	torch.Size([256]) = 0MB
# nets.3.0.web_blocks.1.running_mean -> 	torch.Size([256]) = 0MB
# nets.3.0.web_blocks.1.running_var -> 	torch.Size([256]) = 0MB
# nets.3.0.web_blocks.1.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.3.0.web_blocks.3.weight -> 	torch.Size([256, 256, 3, 3]) = 2MB
# nets.3.0.web_blocks.3.bias -> 	torch.Size([256]) = 0MB
# nets.3.0.web_blocks.4.weight -> 	torch.Size([256]) = 0MB
# nets.3.0.web_blocks.4.bias -> 	torch.Size([256]) = 0MB
# nets.3.0.web_blocks.4.running_mean -> 	torch.Size([256]) = 0MB
# nets.3.0.web_blocks.4.running_var -> 	torch.Size([256]) = 0MB
# nets.3.0.web_blocks.4.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.3.0.cast.0.weight -> 	torch.Size([256, 128, 1, 1]) = 0MB
# nets.3.0.cast.1.weight -> 	torch.Size([256]) = 0MB
# nets.3.0.cast.1.bias -> 	torch.Size([256]) = 0MB
# nets.3.0.cast.1.running_mean -> 	torch.Size([256]) = 0MB
# nets.3.0.cast.1.running_var -> 	torch.Size([256]) = 0MB
# nets.3.0.cast.1.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.3.1.web_blocks.0.weight -> 	torch.Size([256, 256, 3, 3]) = 2MB
# nets.3.1.web_blocks.0.bias -> 	torch.Size([256]) = 0MB
# nets.3.1.web_blocks.1.weight -> 	torch.Size([256]) = 0MB
# nets.3.1.web_blocks.1.bias -> 	torch.Size([256]) = 0MB
# nets.3.1.web_blocks.1.running_mean -> 	torch.Size([256]) = 0MB
# nets.3.1.web_blocks.1.running_var -> 	torch.Size([256]) = 0MB
# nets.3.1.web_blocks.1.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.3.1.web_blocks.3.weight -> 	torch.Size([256, 256, 3, 3]) = 2MB
# nets.3.1.web_blocks.3.bias -> 	torch.Size([256]) = 0MB
# nets.3.1.web_blocks.4.weight -> 	torch.Size([256]) = 0MB
# nets.3.1.web_blocks.4.bias -> 	torch.Size([256]) = 0MB
# nets.3.1.web_blocks.4.running_mean -> 	torch.Size([256]) = 0MB
# nets.3.1.web_blocks.4.running_var -> 	torch.Size([256]) = 0MB
# nets.3.1.web_blocks.4.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.3.2.web_blocks.0.weight -> 	torch.Size([256, 256, 3, 3]) = 2MB
# nets.3.2.web_blocks.0.bias -> 	torch.Size([256]) = 0MB
# nets.3.2.web_blocks.1.weight -> 	torch.Size([256]) = 0MB
# nets.3.2.web_blocks.1.bias -> 	torch.Size([256]) = 0MB
# nets.3.2.web_blocks.1.running_mean -> 	torch.Size([256]) = 0MB
# nets.3.2.web_blocks.1.running_var -> 	torch.Size([256]) = 0MB
# nets.3.2.web_blocks.1.num_batches_tracked -> 	torch.Size([]) = 0MB
# nets.3.2.web_blocks.3.weight -> 	torch.Size([256, 256, 3, 3]) = 2MB
# nets.3.2.web_blocks.3.bias -> 	torch.Size([256]) = 0MB
# nets.3.2.web_blocks.4.weight -> 	torch.Size([256]) = 0MB
# nets.3.2.web_blocks.4.bias -> 	torch.Size([256]) = 0MB
# nets.3.2.web_blocks.4.running_mean -> 	torch.Size([256]) = 0MB
# nets.3.2.web_blocks.4.running_var -> 	torch.Size([256]) = 0MB
# nets.3.2.web_blocks.4.num_batches_tracked -> 	torch.Size([]) = 0MB
# fc.weight -> 	torch.Size([200, 256]) = 0MB
# fc.bias -> 	torch.Size([200]) = 0MB
#
# Restored all variables
# No new variables
# Restored /gdrive/My Drive/colab_files/hw1/tiny_imagenet/logs/0.1/000.pt
#
# Test set: Average loss: 5.4110, Accuracy: 333/8000 (4%)
# Sat Oct 31 06:27:01 2020 Train Epoch: 0 [0/100000 (0%)]	Loss: 4.063553
# Sat Oct 31 06:27:08 2020 Train Epoch: 0 [25600/100000 (26%)]	Loss: 3.861539
# Sat Oct 31 06:27:15 2020 Train Epoch: 0 [51200/100000 (51%)]	Loss: 3.824999
# Sat Oct 31 06:27:22 2020 Train Epoch: 0 [76800/100000 (77%)]	Loss: 3.647383
#
# Test set: Average loss: 4.4552, Accuracy: 837/8000 (10%)
#
# Saved /gdrive/My Drive/colab_files/hw1/tiny_imagenet/logs/0.1/000.pt
#
# Sat Oct 31 06:27:35 2020 Train Epoch: 1 [0/100000 (0%)]	Loss: 3.340507
# Sat Oct 31 06:27:42 2020 Train Epoch: 1 [25600/100000 (26%)]	Loss: 3.431355
# Sat Oct 31 06:27:49 2020 Train Epoch: 1 [51200/100000 (51%)]	Loss: 3.613294
# Sat Oct 31 06:27:56 2020 Train Epoch: 1 [76800/100000 (77%)]	Loss: 3.241559
#
# Test set: Average loss: 3.7962, Accuracy: 1381/8000 (17%)
#
# Saved /gdrive/My Drive/colab_files/hw1/tiny_imagenet/logs/0.1/001.pt
#
# Sat Oct 31 06:28:10 2020 Train Epoch: 2 [0/100000 (0%)]	Loss: 3.142854
# Sat Oct 31 06:28:17 2020 Train Epoch: 2 [25600/100000 (26%)]	Loss: 3.089083
# Sat Oct 31 06:28:24 2020 Train Epoch: 2 [51200/100000 (51%)]	Loss: 3.047105
# Sat Oct 31 06:28:31 2020 Train Epoch: 2 [76800/100000 (77%)]	Loss: 3.170806
#
# Test set: Average loss: 3.5873, Accuracy: 1671/8000 (21%)
#
# Saved /gdrive/My Drive/colab_files/hw1/tiny_imagenet/logs/0.1/002.pt
#
# Sat Oct 31 06:28:45 2020 Train Epoch: 3 [0/100000 (0%)]	Loss: 3.091979
# Sat Oct 31 06:28:52 2020 Train Epoch: 3 [25600/100000 (26%)]	Loss: 2.918377
# Sat Oct 31 06:28:59 2020 Train Epoch: 3 [51200/100000 (51%)]	Loss: 3.184090
# Sat Oct 31 06:29:06 2020 Train Epoch: 3 [76800/100000 (77%)]	Loss: 2.956189
#
# Test set: Average loss: 3.9376, Accuracy: 1433/8000 (18%)
#
# Sat Oct 31 06:29:19 2020 Train Epoch: 4 [0/100000 (0%)]	Loss: 3.025775
# Sat Oct 31 06:29:26 2020 Train Epoch: 4 [25600/100000 (26%)]	Loss: 2.682016
# Sat Oct 31 06:29:33 2020 Train Epoch: 4 [51200/100000 (51%)]	Loss: 2.689780
# Sat Oct 31 06:29:40 2020 Train Epoch: 4 [76800/100000 (77%)]	Loss: 3.040046
#
# Test set: Average loss: 3.5484, Accuracy: 1800/8000 (22%)
#
# Saved /gdrive/My Drive/colab_files/hw1/tiny_imagenet/logs/0.1/004.pt
#
# Sat Oct 31 06:29:54 2020 Train Epoch: 5 [0/100000 (0%)]	Loss: 2.576885
# Sat Oct 31 06:30:01 2020 Train Epoch: 5 [25600/100000 (26%)]	Loss: 2.671414
# Sat Oct 31 06:30:08 2020 Train Epoch: 5 [51200/100000 (51%)]	Loss: 2.716699
# Sat Oct 31 06:30:15 2020 Train Epoch: 5 [76800/100000 (77%)]	Loss: 2.764695
#
# Test set: Average loss: 3.2022, Accuracy: 2234/8000 (28%)
#
# Saved /gdrive/My Drive/colab_files/hw1/tiny_imagenet/logs/0.1/005.pt
#
# Sat Oct 31 06:30:29 2020 Train Epoch: 6 [0/100000 (0%)]	Loss: 2.502194
# Sat Oct 31 06:30:36 2020 Train Epoch: 6 [25600/100000 (26%)]	Loss: 2.717651
# Sat Oct 31 06:30:43 2020 Train Epoch: 6 [51200/100000 (51%)]	Loss: 2.823457
# Sat Oct 31 06:30:50 2020 Train Epoch: 6 [76800/100000 (77%)]	Loss: 2.546901
#
# Test set: Average loss: 3.2829, Accuracy: 2106/8000 (26%)
#
# Sat Oct 31 06:31:04 2020 Train Epoch: 7 [0/100000 (0%)]	Loss: 2.297498
# Sat Oct 31 06:31:11 2020 Train Epoch: 7 [25600/100000 (26%)]	Loss: 2.486019
# Sat Oct 31 06:31:18 2020 Train Epoch: 7 [51200/100000 (51%)]	Loss: 2.472903
# Sat Oct 31 06:31:25 2020 Train Epoch: 7 [76800/100000 (77%)]	Loss: 2.394154
#
# Test set: Average loss: 3.4534, Accuracy: 1955/8000 (24%)
#
# Sat Oct 31 06:31:39 2020 Train Epoch: 8 [0/100000 (0%)]	Loss: 2.260651
# Sat Oct 31 06:31:46 2020 Train Epoch: 8 [25600/100000 (26%)]	Loss: 2.138730
# Sat Oct 31 06:31:53 2020 Train Epoch: 8 [51200/100000 (51%)]	Loss: 2.241953
# Sat Oct 31 06:32:00 2020 Train Epoch: 8 [76800/100000 (77%)]	Loss: 2.474025
#
# Test set: Average loss: 2.9803, Accuracy: 2563/8000 (32%)
#
# Saved /gdrive/My Drive/colab_files/hw1/tiny_imagenet/logs/0.1/008.pt
#
# Sat Oct 31 06:32:14 2020 Train Epoch: 9 [0/100000 (0%)]	Loss: 2.086177
# Sat Oct 31 06:32:21 2020 Train Epoch: 9 [25600/100000 (26%)]	Loss: 2.173626
# Sat Oct 31 06:32:28 2020 Train Epoch: 9 [51200/100000 (51%)]	Loss: 2.362281
# Sat Oct 31 06:32:35 2020 Train Epoch: 9 [76800/100000 (77%)]	Loss: 2.204111
#
# Test set: Average loss: 3.2304, Accuracy: 2277/8000 (28%)
#
# Sat Oct 31 06:32:49 2020 Train Epoch: 10 [0/100000 (0%)]	Loss: 1.860630
# Sat Oct 31 06:32:56 2020 Train Epoch: 10 [25600/100000 (26%)]	Loss: 2.066568
# Sat Oct 31 06:33:03 2020 Train Epoch: 10 [51200/100000 (51%)]	Loss: 2.070679
# Sat Oct 31 06:33:10 2020 Train Epoch: 10 [76800/100000 (77%)]	Loss: 2.272255
#
# Test set: Average loss: 3.2741, Accuracy: 2304/8000 (29%)
#
# Sat Oct 31 06:33:24 2020 Train Epoch: 11 [0/100000 (0%)]	Loss: 1.885729
# Sat Oct 31 06:33:31 2020 Train Epoch: 11 [25600/100000 (26%)]	Loss: 2.036867
# Sat Oct 31 06:33:38 2020 Train Epoch: 11 [51200/100000 (51%)]	Loss: 2.123374
# Sat Oct 31 06:33:45 2020 Train Epoch: 11 [76800/100000 (77%)]	Loss: 1.946790
#
# Test set: Average loss: 3.2678, Accuracy: 2317/8000 (29%)
#
# Sat Oct 31 06:33:58 2020 Train Epoch: 12 [0/100000 (0%)]	Loss: 1.781637
# Sat Oct 31 06:34:06 2020 Train Epoch: 12 [25600/100000 (26%)]	Loss: 1.964656
# Sat Oct 31 06:34:13 2020 Train Epoch: 12 [51200/100000 (51%)]	Loss: 1.865517
# Sat Oct 31 06:34:19 2020 Train Epoch: 12 [76800/100000 (77%)]	Loss: 1.919507
#
# Test set: Average loss: 3.1051, Accuracy: 2516/8000 (31%)
#
# Sat Oct 31 06:34:33 2020 Train Epoch: 13 [0/100000 (0%)]	Loss: 1.739838
# Sat Oct 31 06:34:40 2020 Train Epoch: 13 [25600/100000 (26%)]	Loss: 1.516467
# Sat Oct 31 06:34:47 2020 Train Epoch: 13 [51200/100000 (51%)]	Loss: 1.688417
# Sat Oct 31 06:34:54 2020 Train Epoch: 13 [76800/100000 (77%)]	Loss: 1.807621
#
# Test set: Average loss: 3.0671, Accuracy: 2621/8000 (33%)
#
# Saved /gdrive/My Drive/colab_files/hw1/tiny_imagenet/logs/0.1/013.pt
#
# Sat Oct 31 06:35:08 2020 Train Epoch: 14 [0/100000 (0%)]	Loss: 1.631254
# Sat Oct 31 06:35:15 2020 Train Epoch: 14 [25600/100000 (26%)]	Loss: 1.284735
# Sat Oct 31 06:35:22 2020 Train Epoch: 14 [51200/100000 (51%)]	Loss: 1.687878
# Sat Oct 31 06:35:29 2020 Train Epoch: 14 [76800/100000 (77%)]	Loss: 1.843398
#
# Test set: Average loss: 3.0104, Accuracy: 2635/8000 (33%)
#
# Saved /gdrive/My Drive/colab_files/hw1/tiny_imagenet/logs/0.1/014.pt
#
# Sat Oct 31 06:35:43 2020 Train Epoch: 15 [0/100000 (0%)]	Loss: 1.368790
# Sat Oct 31 06:35:50 2020 Train Epoch: 15 [25600/100000 (26%)]	Loss: 1.591829
# Sat Oct 31 06:35:57 2020 Train Epoch: 15 [51200/100000 (51%)]	Loss: 1.539391
# Sat Oct 31 06:36:04 2020 Train Epoch: 15 [76800/100000 (77%)]	Loss: 1.644958
#
# Test set: Average loss: 3.1738, Accuracy: 2609/8000 (33%)
#
# Sat Oct 31 06:36:18 2020 Train Epoch: 16 [0/100000 (0%)]	Loss: 1.487932
# Sat Oct 31 06:36:25 2020 Train Epoch: 16 [25600/100000 (26%)]	Loss: 1.318872
# Sat Oct 31 06:36:32 2020 Train Epoch: 16 [51200/100000 (51%)]	Loss: 1.594637
# Sat Oct 31 06:36:39 2020 Train Epoch: 16 [76800/100000 (77%)]	Loss: 1.507035
#
# Test set: Average loss: 3.1905, Accuracy: 2590/8000 (32%)
#
# Sat Oct 31 06:36:53 2020 Train Epoch: 17 [0/100000 (0%)]	Loss: 1.420566
# Sat Oct 31 06:37:00 2020 Train Epoch: 17 [25600/100000 (26%)]	Loss: 1.227720
# Sat Oct 31 06:37:07 2020 Train Epoch: 17 [51200/100000 (51%)]	Loss: 1.384863
# Sat Oct 31 06:37:14 2020 Train Epoch: 17 [76800/100000 (77%)]	Loss: 1.506653
#
# Test set: Average loss: 3.1898, Accuracy: 2585/8000 (32%)
#
# Sat Oct 31 06:37:28 2020 Train Epoch: 18 [0/100000 (0%)]	Loss: 1.255309
# Sat Oct 31 06:37:35 2020 Train Epoch: 18 [25600/100000 (26%)]	Loss: 1.285249
# Sat Oct 31 06:37:42 2020 Train Epoch: 18 [51200/100000 (51%)]	Loss: 1.278286
# Sat Oct 31 06:37:49 2020 Train Epoch: 18 [76800/100000 (77%)]	Loss: 1.314798
#
# Test set: Average loss: 4.0476, Accuracy: 1966/8000 (25%)
#
# Sat Oct 31 06:38:03 2020 Train Epoch: 19 [0/100000 (0%)]	Loss: 1.125095
# Sat Oct 31 06:38:10 2020 Train Epoch: 19 [25600/100000 (26%)]	Loss: 0.997419
# Sat Oct 31 06:38:17 2020 Train Epoch: 19 [51200/100000 (51%)]	Loss: 1.152361
# Sat Oct 31 06:38:24 2020 Train Epoch: 19 [76800/100000 (77%)]	Loss: 1.324309
#
# Test set: Average loss: 3.3633, Accuracy: 2523/8000 (32%)
#
# Sat Oct 31 06:38:38 2020 Train Epoch: 20 [0/100000 (0%)]	Loss: 0.925800
# Sat Oct 31 06:38:45 2020 Train Epoch: 20 [25600/100000 (26%)]	Loss: 1.108835
# Sat Oct 31 06:38:52 2020 Train Epoch: 20 [51200/100000 (51%)]	Loss: 1.133319
# Sat Oct 31 06:38:59 2020 Train Epoch: 20 [76800/100000 (77%)]	Loss: 1.157598
#
# Test set: Average loss: 3.4217, Accuracy: 2511/8000 (31%)
#
# Saved /gdrive/My Drive/colab_files/hw1/tiny_imagenet/logs/0.1/020.pt

# %% [markdown]
# ## TinyImageNet Questions
#
# 1. What design that you tried worked the best? How many epochs were you able to run it for? Provide the same information from CIFAR question 1. This includes things like network design, learning rate, batch size, number of epochs, and other optimization parameters, data augmentation etc. What was the final train loss? Test loss? Test Accuracy? Provide the plots for train loss, test loss, and test accuracy.
#
# Adding more convolutional layers and using residual connections, resulted in the best accuracy. We were able to train the network for 15 epochs. The network architecture is composed of one initial convolution layer and four blocks followed by a fully connected layer. One block contains three sets and one set is composed of two convolutions and batch normalizations with a residual connection afterwards. The parameters used here were the same parameters that worked well on CIFAR, that is a batch size of 254, learning rate of 0.01, momentum of 0.9, and a weight decay of 0.0005. We were not able to train over a range of different parameters due to the significant training time. We acheived an average test loss of 3.4217 and a final training loss of 1.157598. Accuracy is 31% with 2511 correct predicted out of 8000.
# Here are the plots for train loss, test loss, and test accuracy:
#
#
#
#
# 2. Were you able to use larger/deeper networks on TinyImageNet than you used on CIFAR and increase accuracy? If so, why? If not, why not?
#
# As TinyImageNet has more classes to predict compared to CIFAR, the models that performed well on CIFAR does not perform as well. However, building deeper networks does not improve the accuracy and instead ends up overfitting to the training set. This is because as models get deeper, it is harder to update the parameters via backpropogation.
#
# 3. The real ImageNet dataset has significantly larger images. How would you change your network design if the images were twice as large? How about smaller than Tiny ImageNet? How do you think your accuracy would change? This is open-ended, but we want a more thought-out answer than "I'd resize the images" or "I'd do a larger pooling stride." You don't have to write code to test your hypothesis.
#
# With a larger image data as input, we should expect more useful features in the image. To extract more of these features, we can add more layers to our network to retrive more useful information without overfitting. On the other hand, if we are dealing with smaller image data, we have less spatial features to learn from. Therefore, we can reduce our network layer to prevent overfitting.

# %% [markdown]
# ![train.png](data:image/png;base64,...)![test.png](data:image/png;base64,...)![test_acc.png](data:image/png;base64,...)

# %% [markdown]
# # Turn-in
#
# Download your `hw1.ipynb` and put it in your `uwnet` repository.
